# %%
import pandas as pd
import numpy as np

# %%
# Import and Read data from dataset
matches = pd.read_csv('./matches.csv')

matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 5        6    2017      Hyderabad  09-04-2017                Gujarat Lions
# 6        7    2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8    2017         Indore  10-04-2017  Royal Challengers Bangalore
# 8        9    2017           Pune  11-04-2017             Delhi Daredevils
# 9       10    2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# 10      11    2017        Kolkata  13-04-2017              Kings XI Punjab
# ...

# %%
#create a dataframe for the match
df=matches[(matches['team1'] == 'Mumbai Indians') & (matches['team2'] == 'Delhi Capitals')]

df
# Out:
#         id  season   city        date           team1           team2  \
# 729  11325    2019  Delhi  18-04-2019  Mumbai Indians  Delhi Capitals
#
#         toss_winner toss_decision  result  dl_applied          winner  \
# 729  Mumbai Indians           bat  normal           0  Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match                    venue  \
# 729           40               0       HH Pandya  Feroz Shah Kotla Ground
#
#          umpire1         umpire2
# 729  Nigel Llong  Bruce Oxenford

# %%
#create a dataframe for the match
de=matches[(matches['team1'] == 'Delhi Capitals') & (matches['team2'] == 'Mumbai Indians')]

de
# Out:
#         id  season    city        date           team1           team2  \
# 698  11139    2019  Mumbai  24-03-2019  Delhi Capitals  Mumbai Indians
#
#         toss_winner toss_decision  result  dl_applied          winner  \
# 698  Mumbai Indians         field  normal           0  Delhi Capitals
#
#      win_by_runs  win_by_wickets player_of_match             venue umpire1  \
# 698           37               0         RR Pant  Wankhede Stadium  S Ravi
#
#             umpire2
# 698  Yeshwant Barde

# %%
#checking for number of wins by each team

noofwins = de.pivot_table(index=['winner'], aggfunc='size')
print (noofwins)


#checking for number of wins by each team

noofwins = df.pivot_table(index=['winner'], aggfunc='size')
print (noofwins)
# Out:
# winner
# Delhi Capitals    1
# dtype: int64
# winner
# Mumbai Indians    1
# dtype: int64

# %%
#create a dataframe for the match
datateam=matches[(matches['team1'] == 'Delhi Daredevils') & (matches['team2'] == 'Mumbai Indians')]

datateam
# Out:
#        id  season    city        date             team1           team2  \
# 237   238    2011   Delhi  10-04-2011  Delhi Daredevils  Mumbai Indians
# 341   342    2012   Delhi  27-04-2012  Delhi Daredevils  Mumbai Indians
# 538   539    2015   Delhi  23-04-2015  Delhi Daredevils  Mumbai Indians
# 555   556    2015  Mumbai  05-05-2015  Delhi Daredevils  Mumbai Indians
# 592   593    2016   Delhi  23-04-2016  Delhi Daredevils  Mumbai Indians
# 690  7948    2018   Delhi  20-05-2018  Delhi Daredevils  Mumbai Indians
#
#           toss_winner toss_decision  result  dl_applied            winner  \
# 237  Delhi Daredevils           bat  normal           0    Mumbai Indians
# 341    Mumbai Indians         field  normal           0  Delhi Daredevils
# 538    Mumbai Indians         field  normal           0  Delhi Daredevils
# 555  Delhi Daredevils           bat  normal           0    Mumbai Indians
# 592    Mumbai Indians         field  normal           0  Delhi Daredevils
# ...

# %%
#create a dataframe for the match
datateam1=matches[(matches['team1'] == 'Mumbai Indians') & (matches['team2'] == 'Delhi Daredevils')]

datateam1
# Out:
#        id  season           city        date           team1  \
# 23     24    2017         Mumbai  22-04-2017  Mumbai Indians
# 43     44    2017          Delhi  06-05-2017  Mumbai Indians
# 81     82    2008         Mumbai  04-05-2008  Mumbai Indians
# 108   109    2008          Delhi  24-05-2008  Mumbai Indians
# 149   150    2009    East London  08-05-2009  Mumbai Indians
# 169   170    2009      Centurion  21-05-2009  Mumbai Indians
# 182   183    2010          Delhi  17-03-2010  Mumbai Indians
# 220   221    2010         Mumbai  13-04-2010  Mumbai Indians
# 281   282    2011         Mumbai  07-05-2011  Mumbai Indians
# 326   327    2012         Mumbai  16-04-2012  Mumbai Indians
# 389   390    2013         Mumbai  09-04-2013  Mumbai Indians
# 407   408    2013          Delhi  21-04-2013  Mumbai Indians
# 472   473    2014        Sharjah  27-04-2014  Mumbai Indians
# 507   508    2014         Mumbai  23-05-2014  Mumbai Indians
# ...

# %%
#checking for number of wins by each team

noofwins = datateam.pivot_table(index=['winner'], aggfunc='size')
print (noofwins)
# Out:
# winner
# Delhi Daredevils    4
# Mumbai Indians      2
# dtype: int64

# %%
#checking for number of wins by each team

noofwins = datateam1.pivot_table(index=['winner'], aggfunc='size')
print (noofwins)
# Out:
# winner
# Delhi Daredevils    7
# Mumbai Indians      9
# dtype: int64

# %%
#importing and reading dataset 

deliveries = pd.read_csv('./deliveries.csv')

deliveries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 5              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 6              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 7              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 8              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 9              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...

# %%
#creating the dataframe for match


dr=deliveries[(deliveries['batting_team'] == 'Mumbai Indians') & (deliveries['bowling_team'] == 'Delhi Daredevils')]

dr
# Out:
#        match_id  inning    batting_team      bowling_team  over  ball  \
# 5512         24       1  Mumbai Indians  Delhi Daredevils     1     1
# 5513         24       1  Mumbai Indians  Delhi Daredevils     1     2
# 5514         24       1  Mumbai Indians  Delhi Daredevils     1     3
# 5515         24       1  Mumbai Indians  Delhi Daredevils     1     4
# 5516         24       1  Mumbai Indians  Delhi Daredevils     1     5
# 5517         24       1  Mumbai Indians  Delhi Daredevils     1     6
# 5518         24       1  Mumbai Indians  Delhi Daredevils     1     7
# 5519         24       1  Mumbai Indians  Delhi Daredevils     2     1
# 5520         24       1  Mumbai Indians  Delhi Daredevils     2     2
# 5521         24       1  Mumbai Indians  Delhi Daredevils     2     3
# 5522         24       1  Mumbai Indians  Delhi Daredevils     2     4
# 5523         24       1  Mumbai Indians  Delhi Daredevils     2     5
# ...

# %%
# checking the noballs frequency for CSK bowling

noball = dr.pivot_table(index=['noball_runs'], aggfunc='size')

print (noball)
# Out:
# noball_runs
# 0    1729
# 1      11
# 2       1
# dtype: int64

# %%
# finding the batsman name

batname = dr.pivot_table(index=['batsman'], aggfunc='size')
print (batname)
# Out:
# batsman
# A Symonds              4
# AC Blizzard           27
# AM Nayar              41
# AM Rahane             55
# AP Tare               10
# AT Rayudu            162
# C Madan               21
# CJ McKay              15
# DJ Bravo              41
# DJ Jacobs             16
# DJ Thornely           24
# DR Smith              29
# DS Kulkarni            4
# HH Pandya             40
# Harbhajan Singh       53
# JC Buttler            20
# JP Duminy             25
# KA Pollard           130
# KD Karthik            87
# KH Pandya             16
# L Ronchi               3
# LMP Simmons           44
# MG Johnson             3
# MJ McClenaghan         1
# MM Patel               5
# Mohammad Ashraful     12
# N Rana                 9
# PA Patel              36
# PP Ojha               12
# PR Shah               35
# RE Levi                4
# RG Sharma            206
# RJ Peterson            2
# RP Singh               5
# RR Raje                7
# RT Ponting             6
# ...

# %%
#creating dataframe for pandaya batting
batting=dr[(dr['batsman'] == 'HH Pandya') ]

batting
# Out:
#        match_id  inning    batting_team      bowling_team  over  ball  \
# 5594         24       1  Mumbai Indians  Delhi Daredevils    13     6
# 5595         24       1  Mumbai Indians  Delhi Daredevils    13     7
# 5599         24       1  Mumbai Indians  Delhi Daredevils    14     4
# 5602         24       1  Mumbai Indians  Delhi Daredevils    15     1
# 5606         24       1  Mumbai Indians  Delhi Daredevils    15     5
# 5611         24       1  Mumbai Indians  Delhi Daredevils    16     4
# 5613         24       1  Mumbai Indians  Delhi Daredevils    16     6
# 5614         24       1  Mumbai Indians  Delhi Daredevils    17     1
# 5615         24       1  Mumbai Indians  Delhi Daredevils    17     2
# 5616         24       1  Mumbai Indians  Delhi Daredevils    17     3
# 5618         24       1  Mumbai Indians  Delhi Daredevils    17     5
# 5621         24       1  Mumbai Indians  Delhi Daredevils    18     2
# ...

# %%
score = batting.pivot_table(index=['total_runs'], aggfunc='size')

print (score)
# Out:
# total_runs
# 0.0    13
# 1.0    19
# 2.0     1
# 3.0     1
# 4.0     1
# 6.0     5
# dtype: int64

# %%
import statistics

# %%
#creating the dataframe for match


dr=deliveries[(deliveries['batting_team'] == 'Mumbai Indians') & (deliveries['bowling_team'] == 'Delhi Daredevils')]

dr
# Out:
#        match_id  inning    batting_team      bowling_team  over  ball  \
# 5512         24       1  Mumbai Indians  Delhi Daredevils     1     1
# 5513         24       1  Mumbai Indians  Delhi Daredevils     1     2
# 5514         24       1  Mumbai Indians  Delhi Daredevils     1     3
# 5515         24       1  Mumbai Indians  Delhi Daredevils     1     4
# 5516         24       1  Mumbai Indians  Delhi Daredevils     1     5
# 5517         24       1  Mumbai Indians  Delhi Daredevils     1     6
# 5518         24       1  Mumbai Indians  Delhi Daredevils     1     7
# 5519         24       1  Mumbai Indians  Delhi Daredevils     2     1
# 5520         24       1  Mumbai Indians  Delhi Daredevils     2     2
# 5521         24       1  Mumbai Indians  Delhi Daredevils     2     3
# 5522         24       1  Mumbai Indians  Delhi Daredevils     2     4
# 5523         24       1  Mumbai Indians  Delhi Daredevils     2     5
# ...

# %%
bat = dr.pivot_table(index=['bowler'], aggfunc='size')
print (bat)
# Out:
# bowler
# A Mishra            167
# A Nehra              77
# AB Agarkar           89
# AB Dinda             12
# AB McDonald          24
# AD Russell            6
# AJ Finch             13
# AM Salvi             26
# B Geeves             25
# BMAJ Mendis          12
# CH Morris            25
# CJ Anderson          13
# DP Nannes            80
# GD McGrath           49
# IK Pathan           142
# JR Hopes             24
# K Rabada             54
# M Morkel            129
# MF Maharoof          55
# Mohammad Asif        27
# Mohammed Shami       12
# PD Collingwood       24
# PJ Cummins           53
# PJ Sangwan          131
# R Bhatia             62
# RE van der Merwe     48
# S Ladda              30
# S Nadeem            115
# Shoaib Malik          6
# UT Yadav            108
# V Sehwag              6
# VY Mahesh            48
# Z Khan               49
# dtype: int64

# %%
bowl=dr.loc[dr['bowler'] == 'K Rabada']

# %%
bowl
# Out:
#        match_id  inning    batting_team      bowling_team  over  ball  \
# 5512         24       1  Mumbai Indians  Delhi Daredevils     1     1
# 5513         24       1  Mumbai Indians  Delhi Daredevils     1     2
# 5514         24       1  Mumbai Indians  Delhi Daredevils     1     3
# 5515         24       1  Mumbai Indians  Delhi Daredevils     1     4
# 5516         24       1  Mumbai Indians  Delhi Daredevils     1     5
# 5517         24       1  Mumbai Indians  Delhi Daredevils     1     6
# 5518         24       1  Mumbai Indians  Delhi Daredevils     1     7
# 5533         24       1  Mumbai Indians  Delhi Daredevils     4     1
# 5534         24       1  Mumbai Indians  Delhi Daredevils     4     2
# 5535         24       1  Mumbai Indians  Delhi Daredevils     4     3
# 5536         24       1  Mumbai Indians  Delhi Daredevils     4     4
# 5537         24       1  Mumbai Indians  Delhi Daredevils     4     5
# ...
